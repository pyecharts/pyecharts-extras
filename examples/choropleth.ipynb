# %%
from pyecharts_extras import ChoroplethMap

value = ["A", "B", "C", "THIS_KEY_IS_NOT_IN_HTML", "A"]
attr = ["福建", "山东", "北京", "上海", "西藏"]
legends = [
        {"tag": "A", "label": "test a", "color": "blue"},
        {"tag": "B", "label": "test b", "color": "yellow"},
        {"tag": "C", "label": "test c", "color": "green"},
        {"tag": "THIS_KEY_IS_NOT_IN_HTML", "label": "test d", "color": "red"},
    ]
map = ChoroplethMap("Choropleth map - 等值区域图示例", width=1200, height=600)
map.add("", attr, value, legends, maptype="china", is_label_show=True)
map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'china': '/nbextensions/echarts-countries-js/china'
#         }
#     });
# </script>
#     <div id="4fe6b1e1e20f4a85ad8f9892ad8d9057" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#
# var myChart_4fe6b1e1e20f4a85ad8f9892ad8d9057 = echarts.init(document.getElementById('4fe6b1e1e20f4a85ad8f9892ad8d9057'), 'light', {renderer: 'canvas'});
#
# var option_4fe6b1e1e20f4a85ad8f9892ad8d9057 = {
#     "title": [
#         {
#             "text": "Choropleth map - \u7b49\u503c\u533a\u57df\u56fe\u793a\u4f8b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 4178088,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 3
#                 }
#             ],
#             "roam": true,
#             "showLegendSymbol": false
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "text": [
#             "high",
#             "low"
#         ],
#         "textStyle": {
#             "color": [
#                 "black"
#             ]
#         },
#         "inRange": {
#             "color": [
#                 "blue",
#                 "yellow",
#                 "green",
#                 "red"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "left",
#         "top": "bottom",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "min": 3,
#                 "max": 3.1,
#                 "label": "test a"
#             },
#             {
#                 "min": 2,
#                 "max": 2.1,
#                 "label": "test b"
#             },
#             {
#                 "min": 1,
#                 "max": 1.1,
#                 "label": "test c"
#             },
#             {
#                 "min": 0,
#                 "max": 0.1,
#                 "label": "test d"
#             }
#         ]
#     }
# };
# myChart_4fe6b1e1e20f4a85ad8f9892ad8d9057.setOption(option_4fe6b1e1e20f4a85ad8f9892ad8d9057);
#
#     });
# </script>
